# %%
import pandas as pd
import pickle
import numpy as np
import pathlib

# %%
file = pathlib.Path("phase2/0/phase2_5_to_10_qubits/AF-5PTI_63_66_3_2_layers.npz")
data = np.load(file, allow_pickle=True)
data
# Out:
# NpzFile 'phase2/0/phase2_5_to_10_qubits/AF-5PTI_63_66_3_2_layers.npz' with keys: cost_history, target_probs, target_indices, best_target_index, conformation_map...

# %%
# Out:
# (30, 2, 2)
