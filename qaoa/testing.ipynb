# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
with open("energies/5PTI_20_24_4.pkl", 'rb') as f:
    step1_data = pickle.load(f)
hpc_results = np.load("qaoa_results/5PTI_qaoa_results.npz", allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 with open("energies/5PTI_20_24_4.pkl", 'rb') as f:
#       2     step1_data = pickle.load(f)
#       3 hpc_results = np.load("qaoa_results/5PTI_qaoa_results.npz", allow_pickle=True)
#
# File ~/Documents/uni/Dissertation/qml_protein_folding/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'energies/5PTI_20_24_4.pkl'

# %%
hpc_results
# Out:
# NpzFile 'qaoa_results/5PTI_qaoa_results.npz' with keys: cost_history, target_probs, target_indices, best_target_index, conformation_map

# %%
hpc_results["cost_history"]
# Out:
# array([[-38.12735 , -38.23322 , -38.342278, ..., -45.034737, -45.03818 ,
#         -45.04149 ],
#        [-39.90903 , -40.048122, -40.187054, ..., -44.273415, -44.295944,
#         -44.318645],
#        [-39.10542 , -39.235012, -39.365532, ..., -44.655556, -44.658005,
#         -44.66046 ],
#        ...,
#        [-42.311153, -42.408474, -42.502384, ..., -45.085716, -45.086483,
#         -45.08723 ],
#        [-43.77498 , -43.860035, -43.939922, ..., -45.029686, -45.033524,
#         -45.03725 ],
#        [-42.039913, -42.156994, -42.273106, ..., -44.869316, -44.871994,
#         -44.874657]], shape=(30, 150), dtype=float32)

# %%
hpc_results["conformation_map"]
# Out:
# array([{'probabilities': [0.9631711840629578, 0.4035866856575012, 0.5258101224899292, 0.8059559464454651, 0.7227773070335388, 0.9387157559394836, 0.9416784644126892, 0.6503182053565979, 0.9701099991798401, 0.7965054512023926, 0.82489013671875, 0.9920331239700317, 0.16697494685649872, 0.5946615934371948, 0.9789844751358032, 0.863602340221405, 0.8985686898231506, 0.5768957138061523, 0.28565144538879395, 0.9999999403953552, 0.09505504369735718, 0.9255955815315247, 0.48720014095306396, 0.20224633812904358, 0.973434329032898, 0.8329682946205139, 0.48821189999580383, 0.9590849280357361, 0.8382482528686523, 0.8495725393295288], 'conformation_data': Conformation(idx=10376, bitstring=[1, 0, 1, 0, 0, 0, 1, 0, 0, 0, 1, 0, 0, 0], qubo_energy=np.float64(-45.1133918762207))}],
#       dtype=object)

# %%
import pathlib
energy_files = list(pathlib.Path("energies/small").glob("*.pkl"))
for energy_file in energy_files:
    file = energy_file.as_posix()
    artifact_base = file.split("/")[-1].split(".")[0]
    print(artifact_base)
# Out:
# 5PTI_22_28_4
# 5PTI_18_22_4
# 5PTI_18_22_5
# 5PTI_22_28_5
# 5PTI_21_25_5
# 5PTI_21_25_4
# 5PTI_20_25_4
# 5PTI_20_24_4
# 5PTI_18_23_4
# 5PTI_19_23_4
# 5PTI_19_23_5
# 5PTI_22_27_4
# 5PTI_22_27_5
# 5PTI_22_26_4
# 5PTI_22_26_5
